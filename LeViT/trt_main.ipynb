# %%
import levit 
import levit_c 
import torch 
import tensorrt as trt 
from cuda import cudart
import numpy as np

import trt_inference 
import trt_convert_onnx 
import trt_build_engine
import sys 

sys.path.append("/home/wentaoy/BraggNN")

# %%
from model import BraggNN
my_model  = BraggNN(imgsz=11, fcsz=(16, 8, 4, 2))
my_model_fn = "../../BraggNN/models/fc16_8_4_2-sz11.pth" 
my_model.load_state_dict(torch.load(my_model_fn, map_location=torch.device('cpu')))
onnx_path = "./test_onnx.onnx"

input_tensor = torch.randn(16,1,11,11)
torch.onnx.export(my_model,               # model being run
                  input_tensor,                         # model input (or a tuple for multiple inputs)
                  onnx_path,   # where to save the model (can be a file or file-like object)
                  export_params=True,        # store the trained parameter weights inside the model file
                  opset_version=11,          # the ONNX version to export the model to
                  do_constant_folding=True, 
                  input_names = ['input'],   # the model's input names
                  output_names = ['output'], # the model's output names
                  dynamic_axes={'input' : {0 : 'batch_size'},    # variable length axes
                                'output' : {0 : 'batch_size'}})  # whether to execute constant folding for optimization)
trt_build_engine.setup_engine(onnx_path="./test_onnx.onnx",trtfile="./test_plan.plan",min_shape=(1,1,11,11),common_shape=(16,1,11,11),max_shape=(32,1,11,11))

# %%
my_engine = trt_build_engine.load_engine("./test_plan.plan")

# %%
import tensorrt as trt 
from cuda import cudart
import numpy as np

from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from PIL import Image
import trt_build_engine 
import os 
# from datasets import build_dataset

def inference(engine,batch_size,input_data):
    context = engine.create_execution_context()
    context.set_binding_shape(0,[batch_size, 1, 11,11])

    _, stream = cudart.cudaStreamCreate()
    inputHost = np.ascontiguousarray(input_data.reshape(-1))
    outputHost = np.empty(context.get_binding_shape(1),dtype = trt.nptype(engine.get_binding_dtype(1)))

    _, inputDevice = cudart.cudaMallocAsync(inputHost.nbytes,stream)
    _, outputDevice = cudart.cudaMallocAsync(outputHost.nbytes,stream)

    
    cudart.cudaMemcpyAsync(inputDevice,inputHost.ctypes.data,inputHost.nbytes,cudart.cudaMemcpyKind.cudaMemcpyHostToDevice,stream)
    
    context.execute_async_v2([int(inputDevice),int(outputDevice)],stream)

    cudart.cudaMemcpyAsync(outputHost.ctypes.data,outputDevice,outputHost.nbytes,cudart.cudaMemcpyKind.cudaMemcpyDeviceToHost,stream)
    cudart.cudaStreamSynchronize(stream)

    cudart.cudaStreamDestroy(stream)
    cudart.cudaFree(inputDevice)
    cudart.cudaFree(outputDevice)
    return outputHost

# %%
my_input = np.random.randn(16,1,11,11).astype(np.float32)
my_input_tensor = torch.from_numpy(my_input)

# %%
my_output = inference(my_engine,16,my_input.astype(np.float32))
my_out_tensor = my_model(my_input_tensor)
# Out:
# [05/27/2022-12:52:25] [TRT] [V] Using cublas as a tactic source
# [05/27/2022-12:52:25] [TRT] [W] TensorRT was linked against cuBLAS/cuBLAS LT 11.8.0 but loaded cuBLAS/cuBLAS LT 11.5.1
# [05/27/2022-12:52:25] [TRT] [I] [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +0, GPU +8, now: CPU 1035, GPU 635 (MiB)
# [05/27/2022-12:52:25] [TRT] [V] Total per-runner device persistent memory is 1536
# [05/27/2022-12:52:25] [TRT] [V] Total per-runner host persistent memory is 14592
# [05/27/2022-12:52:25] [TRT] [V] Allocated activation device memory of size 3162624
# [05/27/2022-12:52:25] [TRT] [I] [MemUsageChange] TensorRT-managed allocation in IExecutionContext creation: CPU +0, GPU +3, now: CPU 0, GPU 3 (MiB)

# %%
my_output
# Out:
# array([[2.946626 , 4.817519 ],
#        [2.1243587, 3.0912056],
#        [2.968986 , 0.954828 ],
#        [1.755752 , 1.7829952],
#        [1.5640985, 0.9984462],
#        [1.5669798, 0.9349642],
#        [1.9920723, 1.3910123],
#        [2.2827024, 2.6263838],
#        [3.0488167, 4.55049  ],
#        [3.9996562, 6.26191  ],
#        [2.700595 , 3.6245704],
#        [3.8992593, 4.8770175],
#        [2.0428529, 2.8271317],
#        [1.6770633, 1.5390544],
#        [1.0882812, 1.3045433],
#        [3.2923229, 2.749569 ]], dtype=float32)

# %%
my_out_tensor
# Out:
# tensor([[2.9487, 4.8205],
#         [2.1217, 3.0876],
#         [2.9687, 0.9558],
#         [1.7593, 1.7867],
#         [1.5645, 0.9982],
#         [1.5674, 0.9361],
#         [1.9883, 1.3909],
#         [2.2868, 2.6371],
#         [3.0540, 4.5593],
#         [4.0004, 6.2618],
#         [2.7031, 3.6269],
#         [3.9001, 4.8796],
#         [2.0434, 2.8281],
#         [1.6739, 1.5430],
#         [1.0880, 1.3048],
#         [3.2928, 2.7526]], grad_fn=<AddmmBackward0>)

# %%
engine_str,logger = trt_build_engine.setup_engine(max_batch_size = 512,
                 max_workspace_size_n = 4,
                 onnx_path = "./onnx_models/levit_128_onnx.onnx",
                 trtfile = "./trt_plans/model_128.plan",
                 min_shape = (2,3,224,224),
                 common_shape = (4,3,224,224),
                 max_shape = (16,3,224,224)
                 )

# %%
engine = trt_build_engine.load_engine("./trt_plans/model_128S.plan")
# Out:
# [05/26/2022-20:09:21] [TRT] [I] [MemUsageChange] Init CUDA: CPU +201, GPU +0, now: CPU 322, GPU 373 (MiB)
# [05/26/2022-20:09:21] [TRT] [I] Loaded engine size: 31 MiB
# [05/26/2022-20:09:22] [TRT] [V] Using cublas as a tactic source
# [05/26/2022-20:09:22] [TRT] [W] TensorRT was linked against cuBLAS/cuBLAS LT 11.8.0 but loaded cuBLAS/cuBLAS LT 11.5.1
# [05/26/2022-20:09:22] [TRT] [I] [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +226, GPU +92, now: CPU 576, GPU 497 (MiB)
# [05/26/2022-20:09:22] [TRT] [V] Deserialization required 398358 microseconds.
# [05/26/2022-20:09:22] [TRT] [I] [MemUsageChange] TensorRT-managed allocation in engine deserialization: CPU +0, GPU +30, now: CPU 0, GPU 30 (MiB)

# %%
input_tensor = np.random.rand(2,3,224,224).astype(np.float32)

# %%
trt_inference.inference(engine,2,input_tensor)
# Out:
# [05/26/2022-20:09:29] [TRT] [V] Using cublas as a tactic source
# [05/26/2022-20:09:29] [TRT] [W] TensorRT was linked against cuBLAS/cuBLAS LT 11.8.0 but loaded cuBLAS/cuBLAS LT 11.5.1
# [05/26/2022-20:09:29] [TRT] [I] [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +0, GPU +8, now: CPU 546, GPU 497 (MiB)
# [05/26/2022-20:09:29] [TRT] [V] Total per-runner device persistent memory is 103424
# [05/26/2022-20:09:29] [TRT] [V] Total per-runner host persistent memory is 45552
# [05/26/2022-20:09:29] [TRT] [V] Allocated activation device memory of size 21375488
# [05/26/2022-20:09:29] [TRT] [I] [MemUsageChange] TensorRT-managed allocation in IExecutionContext creation: CPU +0, GPU +21, now: CPU 0, GPU 51 (MiB)
# array([[-0.08842054, -0.85783243,  0.3030634 , ...,  0.73470837,
#          1.1878492 ,  0.11229506],
#        [ 0.25198007, -0.6299014 ,  0.4541248 , ...,  0.70646733,
#          1.7449799 ,  0.28991875]], dtype=float32)

# %%
my_model = levit.LeViT_128S(pretrained=True,distillation=True)

# %%
import cv2 
from PIL import Image
output = cv2.imread("../../data/img/ILSVRC2012_val_00000001.JPEG").transpose(2,0,1).astype(np.float32)
# output = cv2.resize(output,(224,224)).astype(np.uint8)
input_tensor = torch.from_numpy(output)

# %%
input_tensor.size()
# Out:
# torch.Size([3, 375, 500])

# %%
input_tensor.size()
# Out:
# torch.Size([224, 224, 3])

# %%
my_model(input_tensor.unsqueeze(0))

# %%
input_tensor.size()
# Out:
# torch.Size([224, 224, 500])

# %%
np.shape(output.transpose(2,0,1))
# Out:
# (3, 224, 224)

# %%
output
# Out:
# array([[[189, 187, 177],
#         [191, 189, 179],
#         [193, 191, 181],
#         ...,
#         [201, 201, 189],
#         [198, 198, 186],
#         [197, 197, 185]],
#
#        [[191, 189, 179],
#         [192, 190, 180],
#         [192, 190, 180],
#         ...,
#         [199, 198, 188],
#         [197, 196, 186],
#         [198, 197, 187]],
#
#        [[189, 189, 177],
#         [192, 191, 181],
#         [191, 190, 180],
#         ...,
#         [197, 197, 187],
#         [195, 195, 186],
#         [193, 193, 183]],
#
#        ...,
#
#        [[156, 162, 162],
#         [162, 169, 164],
#         [174, 180, 175],
#         ...,
#         [172, 179, 175],
#         [179, 187, 182],
#         [171, 178, 174]],
#
#        [[158, 165, 163],
#         [157, 164, 159],
#         [165, 171, 167],
#         ...,
#         [171, 182, 179],
#         [171, 182, 180],
#         [157, 164, 163]],
#
#        [[156, 163, 159],
#         [165, 170, 169],
#         [168, 173, 171],
#         ...,
#         [151, 160, 157],
#         [164, 175, 173],
#         [168, 175, 173]]], dtype=uint8)

# %%
output
# Out:
# array([[[188.65866, 186.65866, 176.65866],
#         [191.42169, 189.42169, 179.42169],
#         [192.79747, 190.79747, 180.79747],
#         ...,
#         [200.71622, 200.71622, 188.71622],
#         [198.56233, 198.56233, 186.56233],
#         [197.33705, 197.33705, 185.33705]],
#
#        [[190.99312, 189.01544, 178.99312],
#         [192.28294, 190.29411, 180.29411],
#         [192.25223, 190.17278, 180.35402],
#         ...,
#         [199.07008, 198.07008, 188.07008],
#         [197.13893, 196.13893, 186.13893],
#         [197.97339, 196.97339, 186.97339]],
#
#        [[188.90938, 188.90938, 176.90938],
#         [191.82588, 190.9299 , 180.72188],
#         [191.24033, 189.87054, 180.61012],
#         ...,
#         [196.68005, 197.05058, 187.10565],
#         [195.21072, 195.58125, 185.58125],
#         [192.875  , 193.24554, 183.24554]],
#
#        ...,
#
#        [[155.80281, 162.57066, 161.57066],
#         [162.2822 , 169.01523, 164.3188 ],
#         [173.997  , 180.05205, 175.05205],
#         ...,
#         [171.67929, 179.20311, 174.782  ],
#         [179.28433, 186.91379, 182.54326],
#         [171.6768 , 178.4137 , 174.04317]],
#
#        [[158.18332, 164.80109, 162.58269],
#         [157.63448, 163.78625, 159.08983],
#         [165.61382, 171.53436, 166.77275],
#         ...,
#         [171.09416, 181.91113, 178.90933],
#         [171.27223, 182.24991, 180.23875],
#         [157.08018, 164.30972, 163.2874 ]],
#
#        [[155.97551, 162.97551, 159.46646],
#         [165.06088, 170.16321, 168.67436],
#         [167.81459, 172.81459, 171.42427],
#         ...,
#         [150.93617, 160.44955, 157.34302],
#         [164.2849 , 175.2849 , 172.62195],
#         [167.62819, 175.52328, 173.19739]]], dtype=float32)

# %%
input_tensor.size()
# Out:
# torch.Size([224, 224, 3])

# %%
from PIL import Image
def read_img_numpy(img_path ="../../data/img/ILSVRC2012_val_00000001.JPEG" ):
    out = Image.open(img_path)
    out = out.resize((224,224))
    input_numpy = np.array(out)
    print(np.shape(out))

    try:
        input_numpy = input_numpy.transpose(2,0,1).squeeze().astype(np.float32)
    except:
        print(np.shape(out))
    return input_numpy

# %%
img = read_img_numpy()

# %%
from torch.utils.data import Dataset
import os 
class img_dataset(Dataset):
    def read_img_numpy(self,img_path):
        out = Image.open(img_path)
        out = out.convert("RGB")
        out = out.resize((224,224))
        input_numpy = np.array(out)
        try:
            input_numpy = input_numpy.transpose(2,0,1).squeeze().astype(np.float32)
        except:
            print("error")     
        return input_numpy
    def __init__(self,dir_path):
        self.dir_path = dir_path
        self.image_names = os.listdir(dir_path)
    def __len__(self):
        return len(self.image_names)
    
    def __getitem__(self,idx):
        name = self.image_names[idx]
        ret_numpy_img = self.read_img_numpy(self.dir_path + name)
        return ret_numpy_img

def evaluate(dataset,model):
    engine =

# %%
my_dataset = img_dataset("../../data/img/")

# %%
out = my_dataset[14].transpose(1,2,0)

# %%
np.shape(out)
# Out:
# (224, 224, 3)

# %%
import os 
os.listdir("../../data/img")
# Out:
# ['ILSVRC2012_val_00046108.JPEG',
#  'ILSVRC2012_val_00044030.JPEG',
#  'ILSVRC2012_val_00042898.JPEG',
#  'ILSVRC2012_val_00041481.JPEG',
#  'ILSVRC2012_val_00039493.JPEG',
#  'ILSVRC2012_val_00037864.JPEG',
#  'ILSVRC2012_val_00037578.JPEG',
#  'ILSVRC2012_val_00033095.JPEG',
#  'ILSVRC2012_val_00031091.JPEG',
#  'ILSVRC2012_val_00030154.JPEG',
#  'ILSVRC2012_val_00029819.JPEG',
#  'ILSVRC2012_val_00029360.JPEG',
#  'ILSVRC2012_val_00028777.JPEG',
#  'ILSVRC2012_val_00028553.JPEG',
#  'ILSVRC2012_val_00027575.JPEG',
#  'ILSVRC2012_val_00025401.JPEG',
#  'ILSVRC2012_val_00024855.JPEG',
#  'ILSVRC2012_val_00023386.JPEG',
#  'ILSVRC2012_val_00022933.JPEG',
#  'ILSVRC2012_val_00021388.JPEG',
#  'ILSVRC2012_val_00021057.JPEG',
#  'ILSVRC2012_val_00020878.JPEG',
#  'ILSVRC2012_val_00020583.JPEG',
#  'ILSVRC2012_val_00018525.JPEG',
#  'ILSVRC2012_val_00018454.JPEG',
#  'ILSVRC2012_val_00017993.JPEG',
#  'ILSVRC2012_val_00017876.JPEG',
#  'ILSVRC2012_val_00017779.JPEG',
#  'ILSVRC2012_val_00017000.JPEG',
#  'ILSVRC2012_val_00015032.JPEG',
#  'ILSVRC2012_val_00015001.JPEG',
#  'ILSVRC2012_val_00014754.JPEG',
#  'ILSVRC2012_val_00014387.JPEG',
#  'ILSVRC2012_val_00013565.JPEG',
#  'ILSVRC2012_val_00012972.JPEG',
#  'ILSVRC2012_val_00012573.JPEG',
#  'ILSVRC2012_val_00011147.JPEG',
#  'ILSVRC2012_val_00010821.JPEG',
#  'ILSVRC2012_val_00009710.JPEG',
#  'ILSVRC2012_val_00009613.JPEG',
#  'ILSVRC2012_val_00008531.JPEG',
#  'ILSVRC2012_val_00008105.JPEG',
#  'ILSVRC2012_val_00007396.JPEG',
#  'ILSVRC2012_val_00006633.JPEG',
#  'ILSVRC2012_val_00006536.JPEG',
#  'ILSVRC2012_val_00004741.JPEG',
#  'ILSVRC2012_val_00004086.JPEG',
#  'ILSVRC2012_val_00002418.JPEG',
#  'ILSVRC2012_val_00001837.JPEG',
#  'ILSVRC2012_val_00001545.JPEG',
#  'ILSVRC2012_val_00049144.JPEG',
#  'ILSVRC2012_val_00044766.JPEG',
#  'ILSVRC2012_val_00043342.JPEG',
#  'ILSVRC2012_val_00042053.JPEG',
#  'ILSVRC2012_val_00041912.JPEG',
#  'ILSVRC2012_val_00041735.JPEG',
#  'ILSVRC2012_val_00039569.JPEG',
#  'ILSVRC2012_val_00038565.JPEG',
#  'ILSVRC2012_val_00038554.JPEG',
#  'ILSVRC2012_val_00037989.JPEG',
#  'ILSVRC2012_val_00037347.JPEG',
#  'ILSVRC2012_val_00036247.JPEG',
#  'ILSVRC2012_val_00034121.JPEG',
#  'ILSVRC2012_val_00033126.JPEG',
#  'ILSVRC2012_val_00032793.JPEG',
#  'ILSVRC2012_val_00032727.JPEG',
#  'ILSVRC2012_val_00031693.JPEG',
#  'ILSVRC2012_val_00031508.JPEG',
#  'ILSVRC2012_val_00024169.JPEG',
#  'ILSVRC2012_val_00023428.JPEG',
#  'ILSVRC2012_val_00022982.JPEG',
#  'ILSVRC2012_val_00022593.JPEG',
#  'ILSVRC2012_val_00022137.JPEG',
#  'ILSVRC2012_val_00019861.JPEG',
#  'ILSVRC2012_val_00019639.JPEG',
#  'ILSVRC2012_val_00018989.JPEG',
#  'ILSVRC2012_val_00018931.JPEG',
#  'ILSVRC2012_val_00018912.JPEG',
#  'ILSVRC2012_val_00018526.JPEG',
#  'ILSVRC2012_val_00017126.JPEG',
#  'ILSVRC2012_val_00017046.JPEG',
#  'ILSVRC2012_val_00015377.JPEG',
#  'ILSVRC2012_val_00014787.JPEG',
#  'ILSVRC2012_val_00014357.JPEG',
#  'ILSVRC2012_val_00010062.JPEG',
#  'ILSVRC2012_val_00009546.JPEG',
#  'ILSVRC2012_val_00007801.JPEG',
#  'ILSVRC2012_val_00007446.JPEG',
#  'ILSVRC2012_val_00006720.JPEG',
#  'ILSVRC2012_val_00006704.JPEG',
#  'ILSVRC2012_val_00006093.JPEG',
#  'ILSVRC2012_val_00005279.JPEG',
#  'ILSVRC2012_val_00005139.JPEG',
#  'ILSVRC2012_val_00004684.JPEG',
#  'ILSVRC2012_val_00002397.JPEG',
#  'ILSVRC2012_val_00002059.JPEG',
#  'ILSVRC2012_val_00001812.JPEG',
#  'ILSVRC2012_val_00000500.JPEG',
#  'ILSVRC2012_val_00000441.JPEG',
#  'ILSVRC2012_val_00000079.JPEG',
#  'ILSVRC2012_val_00049908.JPEG',
#  'ILSVRC2012_val_00049044.JPEG',
#  'ILSVRC2012_val_00046981.JPEG',
#  'ILSVRC2012_val_00044882.JPEG',
#  'ILSVRC2012_val_00044767.JPEG',
#  'ILSVRC2012_val_00044217.JPEG',
#  'ILSVRC2012_val_00044187.JPEG',
#  'ILSVRC2012_val_00042233.JPEG',
#  'ILSVRC2012_val_00041092.JPEG',
#  'ILSVRC2012_val_00040556.JPEG',
#  'ILSVRC2012_val_00039850.JPEG',
#  'ILSVRC2012_val_00038583.JPEG',
#  'ILSVRC2012_val_00037767.JPEG',
#  'ILSVRC2012_val_00036709.JPEG',
#  'ILSVRC2012_val_00035604.JPEG',
#  'ILSVRC2012_val_00034744.JPEG',
#  'ILSVRC2012_val_00034516.JPEG',
#  'ILSVRC2012_val_00033581.JPEG',
#  'ILSVRC2012_val_00031864.JPEG',
#  'ILSVRC2012_val_00031747.JPEG',
#  'ILSVRC2012_val_00030255.JPEG',
#  'ILSVRC2012_val_00028908.JPEG',
#  'ILSVRC2012_val_00028901.JPEG',
#  'ILSVRC2012_val_00028425.JPEG',
#  'ILSVRC2012_val_00026509.JPEG',
#  'ILSVRC2012_val_00026094.JPEG',
#  'ILSVRC2012_val_00021475.JPEG',
#  'ILSVRC2012_val_00019665.JPEG',
#  'ILSVRC2012_val_00018141.JPEG',
#  'ILSVRC2012_val_00018055.JPEG',
#  'ILSVRC2012_val_00014928.JPEG',
#  'ILSVRC2012_val_00014877.JPEG',
#  'ILSVRC2012_val_00014845.JPEG',
#  'ILSVRC2012_val_00014711.JPEG',
#  'ILSVRC2012_val_00014147.JPEG',
#  'ILSVRC2012_val_00013045.JPEG',
#  'ILSVRC2012_val_00011202.JPEG',
#  'ILSVRC2012_val_00011009.JPEG',
#  'ILSVRC2012_val_00009888.JPEG',
#  'ILSVRC2012_val_00009673.JPEG',
#  'ILSVRC2012_val_00008727.JPEG',
#  'ILSVRC2012_val_00008137.JPEG',
#  'ILSVRC2012_val_00005018.JPEG',
#  'ILSVRC2012_val_00004782.JPEG',
#  'ILSVRC2012_val_00003435.JPEG',
#  'ILSVRC2012_val_00003140.JPEG',
#  'ILSVRC2012_val_00001917.JPEG',
#  'ILSVRC2012_val_00001467.JPEG',
#  'ILSVRC2012_val_00001039.JPEG',
#  'ILSVRC2012_val_00000719.JPEG',
#  'ILSVRC2012_val_00049243.JPEG',
#  'ILSVRC2012_val_00047506.JPEG',
#  'ILSVRC2012_val_00045073.JPEG',
#  'ILSVRC2012_val_00044098.JPEG',
#  'ILSVRC2012_val_00043621.JPEG',
#  'ILSVRC2012_val_00043547.JPEG',
#  'ILSVRC2012_val_00043429.JPEG',
#  'ILSVRC2012_val_00039816.JPEG',
#  'ILSVRC2012_val_00039462.JPEG',
#  'ILSVRC2012_val_00039155.JPEG',
#  'ILSVRC2012_val_00037839.JPEG',
#  'ILSVRC2012_val_00034714.JPEG',
#  'ILSVRC2012_val_00032561.JPEG',
#  'ILSVRC2012_val_00032326.JPEG',
#  'ILSVRC2012_val_00031902.JPEG',
#  'ILSVRC2012_val_00031182.JPEG',
#  'ILSVRC2012_val_00030759.JPEG',
#  'ILSVRC2012_val_00030393.JPEG',
#  'ILSVRC2012_val_00029588.JPEG',
#  'ILSVRC2012_val_00029531.JPEG',
#  'ILSVRC2012_val_00028002.JPEG',
#  'ILSVRC2012_val_00027566.JPEG',
#  'ILSVRC2012_val_00027171.JPEG',
#  'ILSVRC2012_val_00026369.JPEG',
#  'ILSVRC2012_val_00025138.JPEG',
#  'ILSVRC2012_val_00024899.JPEG',
#  'ILSVRC2012_val_00024474.JPEG',
#  'ILSVRC2012_val_00024441.JPEG',
#  'ILSVRC2012_val_00023822.JPEG',
#  'ILSVRC2012_val_00023229.JPEG',
#  'ILSVRC2012_val_00022053.JPEG',
#  'ILSVRC2012_val_00020036.JPEG',
#  'ILSVRC2012_val_00019350.JPEG',
#  'ILSVRC2012_val_00019166.JPEG',
#  'ILSVRC2012_val_00018157.JPEG',
#  'ILSVRC2012_val_00016803.JPEG',
#  'ILSVRC2012_val_00014491.JPEG',
#  'ILSVRC2012_val_00014122.JPEG',
#  'ILSVRC2012_val_00013786.JPEG',
#  'ILSVRC2012_val_00012461.JPEG',
#  'ILSVRC2012_val_00010159.JPEG',
#  'ILSVRC2012_val_00008260.JPEG',
#  'ILSVRC2012_val_00007316.JPEG',
#  'ILSVRC2012_val_00006994.JPEG',
#  'ILSVRC2012_val_00006598.JPEG',
#  'ILSVRC2012_val_00005029.JPEG',
#  'ILSVRC2012_val_00002607.JPEG',
#  'ILSVRC2012_val_00002133.JPEG',
#  'ILSVRC2012_val_00001922.JPEG',
#  'ILSVRC2012_val_00001672.JPEG',
#  'ILSVRC2012_val_00049364.JPEG',
#  'ILSVRC2012_val_00049089.JPEG',
#  'ILSVRC2012_val_00048955.JPEG',
#  'ILSVRC2012_val_00048639.JPEG',
#  'ILSVRC2012_val_00047109.JPEG',
#  'ILSVRC2012_val_00045861.JPEG',
#  'ILSVRC2012_val_00045280.JPEG',
#  'ILSVRC2012_val_00044804.JPEG',
#  'ILSVRC2012_val_00043157.JPEG',
#  'ILSVRC2012_val_00041762.JPEG',
#  'ILSVRC2012_val_00041718.JPEG',
#  'ILSVRC2012_val_00040570.JPEG',
#  'ILSVRC2012_val_00039505.JPEG',
#  'ILSVRC2012_val_00039386.JPEG',
#  'ILSVRC2012_val_00038926.JPEG',
#  'ILSVRC2012_val_00037925.JPEG',
#  'ILSVRC2012_val_00037195.JPEG',
#  'ILSVRC2012_val_00037191.JPEG',
#  'ILSVRC2012_val_00037153.JPEG',
#  'ILSVRC2012_val_00036220.JPEG',
#  'ILSVRC2012_val_00035680.JPEG',
#  'ILSVRC2012_val_00034470.JPEG',
#  'ILSVRC2012_val_00033834.JPEG',
#  'ILSVRC2012_val_00032581.JPEG',
#  'ILSVRC2012_val_00031713.JPEG',
#  'ILSVRC2012_val_00031048.JPEG',
#  'ILSVRC2012_val_00030776.JPEG',
#  'ILSVRC2012_val_00029636.JPEG',
#  'ILSVRC2012_val_00028758.JPEG',
#  'ILSVRC2012_val_00027245.JPEG',
#  'ILSVRC2012_val_00025983.JPEG',
#  'ILSVRC2012_val_00025330.JPEG',
#  'ILSVRC2012_val_00024187.JPEG',
#  'ILSVRC2012_val_00023303.JPEG',
#  'ILSVRC2012_val_00022363.JPEG',
#  'ILSVRC2012_val_00020399.JPEG',
#  'ILSVRC2012_val_00019175.JPEG',
#  'ILSVRC2012_val_00018479.JPEG',
#  'ILSVRC2012_val_00016508.JPEG',
#  'ILSVRC2012_val_00012515.JPEG',
#  'ILSVRC2012_val_00012471.JPEG',
#  'ILSVRC2012_val_00011082.JPEG',
#  'ILSVRC2012_val_00010722.JPEG',
#  'ILSVRC2012_val_00010099.JPEG',
#  'ILSVRC2012_val_00008463.JPEG',
#  'ILSVRC2012_val_00008441.JPEG',
#  'ILSVRC2012_val_00005900.JPEG',
#  'ILSVRC2012_val_00005331.JPEG',
#  'ILSVRC2012_val_00001195.JPEG',
#  'ILSVRC2012_val_00001001.JPEG',
#  'ILSVRC2012_val_00049592.JPEG',
#  'ILSVRC2012_val_00049047.JPEG',
#  'ILSVRC2012_val_00048803.JPEG',
#  'ILSVRC2012_val_00048298.JPEG',
#  'ILSVRC2012_val_00048159.JPEG',
#  'ILSVRC2012_val_00047980.JPEG',
#  'ILSVRC2012_val_00045950.JPEG',
#  'ILSVRC2012_val_00042750.JPEG',
#  'ILSVRC2012_val_00041655.JPEG',
#  'ILSVRC2012_val_00039584.JPEG',
#  'ILSVRC2012_val_00038581.JPEG',
#  'ILSVRC2012_val_00037665.JPEG',
#  'ILSVRC2012_val_00036593.JPEG',
#  'ILSVRC2012_val_00036505.JPEG',
#  'ILSVRC2012_val_00036438.JPEG',
#  'ILSVRC2012_val_00035902.JPEG',
#  'ILSVRC2012_val_00034787.JPEG',
#  'ILSVRC2012_val_00034350.JPEG',
#  'ILSVRC2012_val_00033779.JPEG',
#  'ILSVRC2012_val_00030442.JPEG',
#  'ILSVRC2012_val_00029398.JPEG',
#  'ILSVRC2012_val_00029076.JPEG',
#  'ILSVRC2012_val_00026658.JPEG',
#  'ILSVRC2012_val_00026562.JPEG',
#  'ILSVRC2012_val_00026410.JPEG',
#  'ILSVRC2012_val_00025927.JPEG',
#  'ILSVRC2012_val_00025663.JPEG',
#  'ILSVRC2012_val_00024955.JPEG',
#  'ILSVRC2012_val_00024460.JPEG',
#  'ILSVRC2012_val_00022511.JPEG',
#  'ILSVRC2012_val_00021940.JPEG',
#  'ILSVRC2012_val_00018870.JPEG',
#  'ILSVRC2012_val_00018380.JPEG',
#  'ILSVRC2012_val_00017049.JPEG',
#  'ILSVRC2012_val_00013939.JPEG',
#  'ILSVRC2012_val_00013579.JPEG',
#  'ILSVRC2012_val_00012628.JPEG',
#  'ILSVRC2012_val_00012388.JPEG',
#  'ILSVRC2012_val_00010621.JPEG',
#  'ILSVRC2012_val_00008662.JPEG',
#  'ILSVRC2012_val_00007797.JPEG',
#  'ILSVRC2012_val_00007610.JPEG',
#  'ILSVRC2012_val_00007563.JPEG',
#  'ILSVRC2012_val_00007036.JPEG',
#  'ILSVRC2012_val_00006705.JPEG',
#  'ILSVRC2012_val_00006123.JPEG',
#  'ILSVRC2012_val_00004497.JPEG',
#  'ILSVRC2012_val_00003694.JPEG',
#  'ILSVRC2012_val_00003664.JPEG',
#  'ILSVRC2012_val_00000691.JPEG',
#  'ILSVRC2012_val_00047883.JPEG',
#  'ILSVRC2012_val_00047079.JPEG',
#  'ILSVRC2012_val_00047046.JPEG',
#  'ILSVRC2012_val_00045681.JPEG',
#  'ILSVRC2012_val_00044906.JPEG',
#  'ILSVRC2012_val_00044293.JPEG',
#  'ILSVRC2012_val_00044222.JPEG',
#  'ILSVRC2012_val_00043865.JPEG',
#  'ILSVRC2012_val_00042683.JPEG',
#  'ILSVRC2012_val_00042297.JPEG',
#  'ILSVRC2012_val_00042244.JPEG',
#  'ILSVRC2012_val_00041969.JPEG',
#  'ILSVRC2012_val_00041658.JPEG',
#  'ILSVRC2012_val_00041230.JPEG',
#  'ILSVRC2012_val_00038573.JPEG',
#  'ILSVRC2012_val_00038095.JPEG',
#  'ILSVRC2012_val_00037142.JPEG',
#  'ILSVRC2012_val_00036864.JPEG',
#  'ILSVRC2012_val_00035950.JPEG',
#  'ILSVRC2012_val_00034785.JPEG',
#  'ILSVRC2012_val_00034449.JPEG',
#  'ILSVRC2012_val_00034288.JPEG',
#  'ILSVRC2012_val_00033363.JPEG',
#  'ILSVRC2012_val_00033173.JPEG',
#  'ILSVRC2012_val_00031933.JPEG',
#  'ILSVRC2012_val_00031554.JPEG',
#  'ILSVRC2012_val_00031287.JPEG',
#  'ILSVRC2012_val_00030522.JPEG',
#  'ILSVRC2012_val_00029100.JPEG',
#  'ILSVRC2012_val_00029060.JPEG',
#  'ILSVRC2012_val_00026443.JPEG',
#  'ILSVRC2012_val_00024086.JPEG',
#  'ILSVRC2012_val_00022406.JPEG',
#  'ILSVRC2012_val_00021950.JPEG',
#  'ILSVRC2012_val_00021672.JPEG',
#  'ILSVRC2012_val_00021588.JPEG',
#  'ILSVRC2012_val_00019348.JPEG',
#  'ILSVRC2012_val_00016743.JPEG',
#  'ILSVRC2012_val_00015875.JPEG',
#  'ILSVRC2012_val_00014224.JPEG',
#  'ILSVRC2012_val_00011649.JPEG',
#  'ILSVRC2012_val_00008601.JPEG',
#  'ILSVRC2012_val_00008020.JPEG',
#  'ILSVRC2012_val_00007489.JPEG',
#  'ILSVRC2012_val_00006747.JPEG',
#  'ILSVRC2012_val_00006173.JPEG',
#  'ILSVRC2012_val_00005933.JPEG',
#  'ILSVRC2012_val_00005104.JPEG',
#  'ILSVRC2012_val_00003972.JPEG',
#  'ILSVRC2012_val_00002867.JPEG',
#  'ILSVRC2012_val_00049577.JPEG',
#  'ILSVRC2012_val_00048719.JPEG',
#  'ILSVRC2012_val_00046491.JPEG',
#  'ILSVRC2012_val_00046237.JPEG',
#  'ILSVRC2012_val_00045650.JPEG',
#  'ILSVRC2012_val_00045161.JPEG',
#  'ILSVRC2012_val_00044959.JPEG',
#  'ILSVRC2012_val_00042242.JPEG',
#  'ILSVRC2012_val_00041511.JPEG',
#  'ILSVRC2012_val_00039953.JPEG',
#  'ILSVRC2012_val_00039768.JPEG',
#  'ILSVRC2012_val_00038764.JPEG',
#  'ILSVRC2012_val_00035276.JPEG',
#  'ILSVRC2012_val_00034051.JPEG',
#  'ILSVRC2012_val_00033908.JPEG',
#  'ILSVRC2012_val_00033801.JPEG',
#  'ILSVRC2012_val_00033481.JPEG',
#  'ILSVRC2012_val_00033356.JPEG',
#  'ILSVRC2012_val_00031043.JPEG',
#  'ILSVRC2012_val_00031004.JPEG',
#  'ILSVRC2012_val_00030635.JPEG',
#  'ILSVRC2012_val_00030340.JPEG',
#  'ILSVRC2012_val_00029528.JPEG',
#  'ILSVRC2012_val_00025871.JPEG',
#  'ILSVRC2012_val_00022305.JPEG',
#  'ILSVRC2012_val_00022065.JPEG',
#  'ILSVRC2012_val_00019586.JPEG',
#  'ILSVRC2012_val_00019218.JPEG',
#  'ILSVRC2012_val_00017678.JPEG',
#  'ILSVRC2012_val_00016270.JPEG',
#  'ILSVRC2012_val_00014777.JPEG',
#  'ILSVRC2012_val_00014515.JPEG',
#  'ILSVRC2012_val_00012238.JPEG',
#  'ILSVRC2012_val_00011633.JPEG',
#  'ILSVRC2012_val_00011532.JPEG',
#  'ILSVRC2012_val_00010936.JPEG',
#  'ILSVRC2012_val_00010564.JPEG',
#  'ILSVRC2012_val_00008724.JPEG',
#  'ILSVRC2012_val_00008490.JPEG',
#  'ILSVRC2012_val_00007163.JPEG',
#  'ILSVRC2012_val_00006908.JPEG',
#  'ILSVRC2012_val_00006833.JPEG',
#  'ILSVRC2012_val_00005856.JPEG',
#  'ILSVRC2012_val_00005062.JPEG',
#  'ILSVRC2012_val_00003598.JPEG',
#  'ILSVRC2012_val_00002149.JPEG',
#  'ILSVRC2012_val_00001189.JPEG',
#  'ILSVRC2012_val_00001051.JPEG',
#  'ILSVRC2012_val_00000996.JPEG',
#  'ILSVRC2012_val_00000124.JPEG',
#  'ILSVRC2012_val_00049440.JPEG',
#  'ILSVRC2012_val_00048562.JPEG',
#  'ILSVRC2012_val_00048052.JPEG',
#  'ILSVRC2012_val_00047476.JPEG',
#  'ILSVRC2012_val_00047416.JPEG',
#  'ILSVRC2012_val_00044836.JPEG',
#  'ILSVRC2012_val_00044632.JPEG',
#  'ILSVRC2012_val_00042553.JPEG',
#  'ILSVRC2012_val_00038694.JPEG',
#  'ILSVRC2012_val_00034605.JPEG',
#  'ILSVRC2012_val_00034448.JPEG',
#  'ILSVRC2012_val_00033808.JPEG',
#  'ILSVRC2012_val_00033512.JPEG',
#  'ILSVRC2012_val_00033014.JPEG',
#  'ILSVRC2012_val_00031923.JPEG',
#  'ILSVRC2012_val_00031099.JPEG',
#  'ILSVRC2012_val_00029812.JPEG',
#  'ILSVRC2012_val_00028096.JPEG',
#  'ILSVRC2012_val_00027218.JPEG',
#  'ILSVRC2012_val_00026378.JPEG',
#  'ILSVRC2012_val_00026314.JPEG',
#  'ILSVRC2012_val_00024885.JPEG',
#  'ILSVRC2012_val_00024557.JPEG',
#  'ILSVRC2012_val_00023840.JPEG',
#  'ILSVRC2012_val_00023604.JPEG',
#  'ILSVRC2012_val_00023601.JPEG',
#  'ILSVRC2012_val_00022596.JPEG',
#  'ILSVRC2012_val_00021385.JPEG',
#  'ILSVRC2012_val_00021378.JPEG',
#  'ILSVRC2012_val_00021334.JPEG',
#  'ILSVRC2012_val_00020970.JPEG',
#  'ILSVRC2012_val_00020816.JPEG',
#  'ILSVRC2012_val_00019859.JPEG',
#  'ILSVRC2012_val_00019510.JPEG',
#  'ILSVRC2012_val_00017137.JPEG',
#  'ILSVRC2012_val_00015789.JPEG',
#  'ILSVRC2012_val_00014921.JPEG',
#  'ILSVRC2012_val_00013423.JPEG',
#  'ILSVRC2012_val_00013377.JPEG',
#  'ILSVRC2012_val_00011585.JPEG',
#  'ILSVRC2012_val_00011137.JPEG',
#  'ILSVRC2012_val_00011071.JPEG',
#  'ILSVRC2012_val_00009697.JPEG',
#  'ILSVRC2012_val_00008870.JPEG',
#  'ILSVRC2012_val_00007769.JPEG',
#  'ILSVRC2012_val_00006100.JPEG',
#  'ILSVRC2012_val_00004254.JPEG',
#  'ILSVRC2012_val_00004113.JPEG',
#  'ILSVRC2012_val_00003705.JPEG',
#  'ILSVRC2012_val_00002684.JPEG',
#  'ILSVRC2012_val_00049970.JPEG',
#  'ILSVRC2012_val_00049607.JPEG',
#  'ILSVRC2012_val_00047159.JPEG',
#  'ILSVRC2012_val_00046363.JPEG',
#  'ILSVRC2012_val_00045383.JPEG',
#  'ILSVRC2012_val_00041686.JPEG',
#  'ILSVRC2012_val_00040262.JPEG',
#  'ILSVRC2012_val_00039318.JPEG',
#  'ILSVRC2012_val_00038849.JPEG',
#  'ILSVRC2012_val_00038591.JPEG',
#  'ILSVRC2012_val_00037923.JPEG',
#  'ILSVRC2012_val_00036093.JPEG',
#  'ILSVRC2012_val_00035156.JPEG',
#  'ILSVRC2012_val_00034913.JPEG',
#  'ILSVRC2012_val_00034391.JPEG',
#  'ILSVRC2012_val_00034234.JPEG',
#  'ILSVRC2012_val_00033023.JPEG',
#  'ILSVRC2012_val_00032814.JPEG',
#  'ILSVRC2012_val_00030743.JPEG',
#  'ILSVRC2012_val_00030046.JPEG',
#  'ILSVRC2012_val_00027903.JPEG',
#  'ILSVRC2012_val_00027356.JPEG',
#  'ILSVRC2012_val_00027350.JPEG',
#  'ILSVRC2012_val_00025515.JPEG',
#  'ILSVRC2012_val_00023681.JPEG',
#  'ILSVRC2012_val_00022119.JPEG',
#  'ILSVRC2012_val_00021443.JPEG',
#  'ILSVRC2012_val_00021114.JPEG',
#  'ILSVRC2012_val_00021039.JPEG',
#  'ILSVRC2012_val_00019892.JPEG',
#  'ILSVRC2012_val_00019890.JPEG',
#  'ILSVRC2012_val_00014629.JPEG',
#  'ILSVRC2012_val_00014096.JPEG',
#  'ILSVRC2012_val_00013850.JPEG',
#  'ILSVRC2012_val_00013429.JPEG',
#  'ILSVRC2012_val_00013148.JPEG',
#  'ILSVRC2012_val_00013139.JPEG',
#  'ILSVRC2012_val_00011080.JPEG',
#  'ILSVRC2012_val_00010338.JPEG',
#  'ILSVRC2012_val_00009121.JPEG',
#  'ILSVRC2012_val_00008799.JPEG',
#  'ILSVRC2012_val_00007521.JPEG',
#  'ILSVRC2012_val_00005464.JPEG',
#  'ILSVRC2012_val_00005455.JPEG',
#  'ILSVRC2012_val_00005253.JPEG',
#  'ILSVRC2012_val_00004738.JPEG',
#  'ILSVRC2012_val_00003594.JPEG',
#  'ILSVRC2012_val_00003313.JPEG',
#  'ILSVRC2012_val_00001619.JPEG',
#  'ILSVRC2012_val_00000980.JPEG',
#  'ILSVRC2012_val_00047936.JPEG',
#  'ILSVRC2012_val_00047673.JPEG',
#  'ILSVRC2012_val_00047210.JPEG',
#  'ILSVRC2012_val_00046192.JPEG',
#  'ILSVRC2012_val_00045508.JPEG',
#  'ILSVRC2012_val_00044873.JPEG',
#  'ILSVRC2012_val_00042039.JPEG',
#  'ILSVRC2012_val_00041471.JPEG',
#  'ILSVRC2012_val_00041312.JPEG',
#  'ILSVRC2012_val_00040931.JPEG',
#  'ILSVRC2012_val_00040559.JPEG',
#  'ILSVRC2012_val_00040211.JPEG',
#  'ILSVRC2012_val_00038419.JPEG',
#  'ILSVRC2012_val_00034911.JPEG',
#  'ILSVRC2012_val_00033954.JPEG',
#  'ILSVRC2012_val_00032709.JPEG',
#  'ILSVRC2012_val_00032383.JPEG',
#  'ILSVRC2012_val_00032228.JPEG',
#  'ILSVRC2012_val_00031710.JPEG',
#  'ILSVRC2012_val_00031367.JPEG',
#  'ILSVRC2012_val_00031055.JPEG',
#  'ILSVRC2012_val_00030666.JPEG',
#  'ILSVRC2012_val_00030655.JPEG',
#  'ILSVRC2012_val_00028576.JPEG',
#  'ILSVRC2012_val_00027332.JPEG',
#  'ILSVRC2012_val_00025619.JPEG',
#  'ILSVRC2012_val_00023600.JPEG',
#  'ILSVRC2012_val_00023332.JPEG',
#  'ILSVRC2012_val_00023035.JPEG',
#  'ILSVRC2012_val_00021394.JPEG',
#  'ILSVRC2012_val_00021304.JPEG',
#  'ILSVRC2012_val_00020887.JPEG',
#  'ILSVRC2012_val_00017784.JPEG',
#  'ILSVRC2012_val_00017263.JPEG',
#  'ILSVRC2012_val_00017235.JPEG',
#  'ILSVRC2012_val_00017118.JPEG',
#  'ILSVRC2012_val_00016914.JPEG',
#  'ILSVRC2012_val_00016204.JPEG',
#  'ILSVRC2012_val_00015079.JPEG',
#  'ILSVRC2012_val_00013140.JPEG',
#  'ILSVRC2012_val_00012745.JPEG',
#  'ILSVRC2012_val_00011994.JPEG',
#  'ILSVRC2012_val_00009028.JPEG',
#  'ILSVRC2012_val_00007225.JPEG',
#  'ILSVRC2012_val_00005550.JPEG',
#  'ILSVRC2012_val_00004846.JPEG',
#  'ILSVRC2012_val_00004068.JPEG',
#  'ILSVRC2012_val_00003307.JPEG',
#  'ILSVRC2012_val_00002588.JPEG',
#  'ILSVRC2012_val_00002436.JPEG',
#  'ILSVRC2012_val_00049487.JPEG',
#  'ILSVRC2012_val_00048901.JPEG',
#  'ILSVRC2012_val_00047410.JPEG',
#  'ILSVRC2012_val_00046304.JPEG',
#  'ILSVRC2012_val_00045844.JPEG',
#  'ILSVRC2012_val_00045464.JPEG',
#  'ILSVRC2012_val_00044863.JPEG',
#  'ILSVRC2012_val_00044295.JPEG',
#  'ILSVRC2012_val_00043870.JPEG',
#  'ILSVRC2012_val_00042822.JPEG',
#  'ILSVRC2012_val_00042382.JPEG',
#  'ILSVRC2012_val_00041883.JPEG',
#  'ILSVRC2012_val_00041720.JPEG',
#  'ILSVRC2012_val_00039872.JPEG',
#  'ILSVRC2012_val_00038377.JPEG',
#  'ILSVRC2012_val_00038073.JPEG',
#  'ILSVRC2012_val_00037306.JPEG',
#  'ILSVRC2012_val_00035142.JPEG',
#  'ILSVRC2012_val_00034381.JPEG',
#  'ILSVRC2012_val_00033160.JPEG',
#  'ILSVRC2012_val_00031730.JPEG',
#  'ILSVRC2012_val_00031673.JPEG',
#  'ILSVRC2012_val_00029561.JPEG',
#  'ILSVRC2012_val_00028295.JPEG',
#  'ILSVRC2012_val_00028100.JPEG',
#  'ILSVRC2012_val_00027119.JPEG',
#  'ILSVRC2012_val_00025672.JPEG',
#  'ILSVRC2012_val_00025374.JPEG',
#  'ILSVRC2012_val_00023378.JPEG',
#  'ILSVRC2012_val_00022850.JPEG',
#  'ILSVRC2012_val_00022051.JPEG',
#  'ILSVRC2012_val_00019913.JPEG',
#  'ILSVRC2012_val_00019790.JPEG',
#  'ILSVRC2012_val_00019420.JPEG',
#  'ILSVRC2012_val_00017571.JPEG',
#  'ILSVRC2012_val_00017455.JPEG',
#  'ILSVRC2012_val_00016534.JPEG',
#  'ILSVRC2012_val_00013871.JPEG',
#  'ILSVRC2012_val_00013539.JPEG',
#  'ILSVRC2012_val_00012217.JPEG',
#  'ILSVRC2012_val_00012040.JPEG',
#  'ILSVRC2012_val_00011028.JPEG',
#  'ILSVRC2012_val_00010315.JPEG',
#  'ILSVRC2012_val_00007693.JPEG',
#  'ILSVRC2012_val_00007046.JPEG',
#  'ILSVRC2012_val_00005160.JPEG',
#  'ILSVRC2012_val_00004705.JPEG',
#  'ILSVRC2012_val_00004328.JPEG',
#  'ILSVRC2012_val_00003519.JPEG',
#  'ILSVRC2012_val_00001160.JPEG',
#  'ILSVRC2012_val_00049650.JPEG',
#  'ILSVRC2012_val_00048760.JPEG',
#  'ILSVRC2012_val_00048436.JPEG',
#  'ILSVRC2012_val_00047146.JPEG',
#  'ILSVRC2012_val_00046390.JPEG',
#  'ILSVRC2012_val_00044772.JPEG',
#  'ILSVRC2012_val_00044473.JPEG',
#  'ILSVRC2012_val_00044091.JPEG',
#  'ILSVRC2012_val_00043845.JPEG',
#  'ILSVRC2012_val_00042912.JPEG',
#  'ILSVRC2012_val_00042249.JPEG',
#  'ILSVRC2012_val_00039060.JPEG',
#  'ILSVRC2012_val_00037323.JPEG',
#  'ILSVRC2012_val_00036061.JPEG',
#  'ILSVRC2012_val_00035120.JPEG',
#  'ILSVRC2012_val_00034893.JPEG',
#  'ILSVRC2012_val_00034056.JPEG',
#  'ILSVRC2012_val_00033916.JPEG',
#  'ILSVRC2012_val_00033232.JPEG',
#  'ILSVRC2012_val_00031787.JPEG',
#  'ILSVRC2012_val_00031355.JPEG',
#  'ILSVRC2012_val_00030619.JPEG',
#  'ILSVRC2012_val_00029646.JPEG',
#  'ILSVRC2012_val_00029392.JPEG',
#  'ILSVRC2012_val_00029157.JPEG',
#  'ILSVRC2012_val_00029152.JPEG',
#  'ILSVRC2012_val_00028694.JPEG',
#  'ILSVRC2012_val_00028642.JPEG',
#  'ILSVRC2012_val_00027862.JPEG',
#  'ILSVRC2012_val_00027305.JPEG',
#  'ILSVRC2012_val_00025884.JPEG',
#  'ILSVRC2012_val_00024967.JPEG',
#  'ILSVRC2012_val_00024462.JPEG',
#  'ILSVRC2012_val_00021608.JPEG',
#  'ILSVRC2012_val_00021483.JPEG',
#  'ILSVRC2012_val_00019318.JPEG',
#  'ILSVRC2012_val_00016964.JPEG',
#  'ILSVRC2012_val_00013930.JPEG',
#  'ILSVRC2012_val_00013524.JPEG',
#  'ILSVRC2012_val_00012899.JPEG',
#  'ILSVRC2012_val_00012446.JPEG',
#  'ILSVRC2012_val_00009435.JPEG',
#  'ILSVRC2012_val_00008433.JPEG',
#  'ILSVRC2012_val_00008335.JPEG',
#  'ILSVRC2012_val_00007726.JPEG',
#  'ILSVRC2012_val_00007547.JPEG',
#  'ILSVRC2012_val_00003691.JPEG',
#  'ILSVRC2012_val_00003327.JPEG',
#  'ILSVRC2012_val_00001925.JPEG',
#  'ILSVRC2012_val_00001568.JPEG',
#  'ILSVRC2012_val_00048123.JPEG',
#  'ILSVRC2012_val_00047276.JPEG',
#  'ILSVRC2012_val_00046629.JPEG',
#  'ILSVRC2012_val_00044642.JPEG',
#  'ILSVRC2012_val_00043776.JPEG',
#  'ILSVRC2012_val_00043201.JPEG',
#  'ILSVRC2012_val_00041705.JPEG',
#  'ILSVRC2012_val_00038257.JPEG',
#  'ILSVRC2012_val_00038247.JPEG',
#  'ILSVRC2012_val_00037960.JPEG',
#  'ILSVRC2012_val_00037230.JPEG',
#  'ILSVRC2012_val_00036890.JPEG',
#  'ILSVRC2012_val_00036433.JPEG',
#  'ILSVRC2012_val_00036267.JPEG',
#  'ILSVRC2012_val_00034040.JPEG',
#  'ILSVRC2012_val_00033476.JPEG',
#  'ILSVRC2012_val_00033222.JPEG',
#  'ILSVRC2012_val_00033200.JPEG',
#  'ILSVRC2012_val_00031965.JPEG',
#  'ILSVRC2012_val_00031068.JPEG',
#  'ILSVRC2012_val_00029262.JPEG',
#  'ILSVRC2012_val_00028706.JPEG',
#  'ILSVRC2012_val_00028459.JPEG',
#  'ILSVRC2012_val_00026017.JPEG',
#  'ILSVRC2012_val_00025437.JPEG',
#  'ILSVRC2012_val_00025098.JPEG',
#  'ILSVRC2012_val_00022490.JPEG',
#  'ILSVRC2012_val_00022438.JPEG',
#  'ILSVRC2012_val_00021896.JPEG',
#  'ILSVRC2012_val_00019130.JPEG',
#  'ILSVRC2012_val_00018296.JPEG',
#  'ILSVRC2012_val_00016603.JPEG',
#  'ILSVRC2012_val_00015730.JPEG',
#  'ILSVRC2012_val_00015670.JPEG',
#  'ILSVRC2012_val_00015082.JPEG',
#  'ILSVRC2012_val_00014911.JPEG',
#  'ILSVRC2012_val_00012298.JPEG',
#  'ILSVRC2012_val_00011985.JPEG',
#  'ILSVRC2012_val_00011749.JPEG',
#  'ILSVRC2012_val_00010516.JPEG',
#  'ILSVRC2012_val_00009247.JPEG',
#  'ILSVRC2012_val_00009007.JPEG',
#  'ILSVRC2012_val_00007088.JPEG',
#  'ILSVRC2012_val_00006146.JPEG',
#  'ILSVRC2012_val_00004671.JPEG',
#  'ILSVRC2012_val_00003953.JPEG',
#  'ILSVRC2012_val_00001779.JPEG',
#  'ILSVRC2012_val_00001228.JPEG',
#  'ILSVRC2012_val_00001225.JPEG',
#  'ILSVRC2012_val_00000462.JPEG',
#  'ILSVRC2012_val_00049940.JPEG',
#  'ILSVRC2012_val_00048532.JPEG',
#  'ILSVRC2012_val_00048454.JPEG',
#  'ILSVRC2012_val_00046052.JPEG',
#  'ILSVRC2012_val_00045962.JPEG',
#  'ILSVRC2012_val_00044623.JPEG',
#  'ILSVRC2012_val_00044142.JPEG',
#  'ILSVRC2012_val_00041812.JPEG',
#  'ILSVRC2012_val_00039566.JPEG',
#  'ILSVRC2012_val_00039208.JPEG',
#  'ILSVRC2012_val_00038381.JPEG',
#  'ILSVRC2012_val_00038179.JPEG',
#  'ILSVRC2012_val_00037536.JPEG',
#  'ILSVRC2012_val_00036679.JPEG',
#  'ILSVRC2012_val_00036470.JPEG',
#  'ILSVRC2012_val_00036256.JPEG',
#  'ILSVRC2012_val_00035712.JPEG',
#  'ILSVRC2012_val_00034924.JPEG',
#  'ILSVRC2012_val_00033613.JPEG',
#  'ILSVRC2012_val_00033426.JPEG',
#  'ILSVRC2012_val_00028792.JPEG',
#  'ILSVRC2012_val_00026994.JPEG',
#  'ILSVRC2012_val_00026157.JPEG',
#  'ILSVRC2012_val_00024502.JPEG',
#  'ILSVRC2012_val_00023894.JPEG',
#  'ILSVRC2012_val_00023771.JPEG',
#  'ILSVRC2012_val_00020844.JPEG',
#  'ILSVRC2012_val_00019852.JPEG',
#  'ILSVRC2012_val_00019515.JPEG',
#  'ILSVRC2012_val_00018891.JPEG',
#  'ILSVRC2012_val_00018408.JPEG',
#  'ILSVRC2012_val_00018232.JPEG',
#  'ILSVRC2012_val_00018191.JPEG',
#  'ILSVRC2012_val_00017225.JPEG',
#  'ILSVRC2012_val_00016032.JPEG',
#  'ILSVRC2012_val_00015616.JPEG',
#  'ILSVRC2012_val_00015384.JPEG',
#  'ILSVRC2012_val_00014703.JPEG',
#  'ILSVRC2012_val_00014377.JPEG',
#  'ILSVRC2012_val_00014111.JPEG',
#  'ILSVRC2012_val_00012760.JPEG',
#  'ILSVRC2012_val_00011478.JPEG',
#  'ILSVRC2012_val_00011361.JPEG',
#  'ILSVRC2012_val_00008043.JPEG',
#  'ILSVRC2012_val_00005142.JPEG',
#  'ILSVRC2012_val_00004668.JPEG',
#  'ILSVRC2012_val_00003809.JPEG',
#  'ILSVRC2012_val_00003128.JPEG',
#  'ILSVRC2012_val_00003009.JPEG',
#  'ILSVRC2012_val_00002489.JPEG',
#  'ILSVRC2012_val_00049495.JPEG',
#  'ILSVRC2012_val_00049395.JPEG',
#  'ILSVRC2012_val_00048791.JPEG',
#  'ILSVRC2012_val_00048548.JPEG',
#  'ILSVRC2012_val_00048509.JPEG',
#  'ILSVRC2012_val_00048212.JPEG',
#  'ILSVRC2012_val_00047970.JPEG',
#  'ILSVRC2012_val_00047656.JPEG',
#  'ILSVRC2012_val_00047321.JPEG',
#  'ILSVRC2012_val_00046649.JPEG',
#  'ILSVRC2012_val_00044692.JPEG',
#  'ILSVRC2012_val_00044007.JPEG',
#  'ILSVRC2012_val_00043422.JPEG',
#  'ILSVRC2012_val_00041922.JPEG',
#  'ILSVRC2012_val_00040206.JPEG',
#  'ILSVRC2012_val_00038815.JPEG',
#  'ILSVRC2012_val_00036430.JPEG',
#  'ILSVRC2012_val_00035687.JPEG',
#  'ILSVRC2012_val_00030212.JPEG',
#  'ILSVRC2012_val_00029231.JPEG',
#  'ILSVRC2012_val_00028812.JPEG',
#  'ILSVRC2012_val_00027700.JPEG',
#  'ILSVRC2012_val_00027483.JPEG',
#  'ILSVRC2012_val_00027193.JPEG',
#  'ILSVRC2012_val_00025799.JPEG',
#  'ILSVRC2012_val_00024993.JPEG',
#  'ILSVRC2012_val_00024753.JPEG',
#  'ILSVRC2012_val_00021164.JPEG',
#  'ILSVRC2012_val_00020061.JPEG',
#  'ILSVRC2012_val_00019894.JPEG',
#  'ILSVRC2012_val_00019587.JPEG',
#  'ILSVRC2012_val_00018983.JPEG',
#  'ILSVRC2012_val_00017962.JPEG',
#  'ILSVRC2012_val_00017572.JPEG',
#  'ILSVRC2012_val_00017061.JPEG',
#  'ILSVRC2012_val_00016258.JPEG',
#  'ILSVRC2012_val_00010761.JPEG',
#  'ILSVRC2012_val_00010634.JPEG',
#  'ILSVRC2012_val_00010602.JPEG',
#  'ILSVRC2012_val_00010061.JPEG',
#  'ILSVRC2012_val_00009035.JPEG',
#  'ILSVRC2012_val_00007339.JPEG',
#  'ILSVRC2012_val_00007015.JPEG',
#  'ILSVRC2012_val_00006120.JPEG',
#  'ILSVRC2012_val_00004921.JPEG',
#  'ILSVRC2012_val_00004369.JPEG',
#  'ILSVRC2012_val_00004310.JPEG',
#  'ILSVRC2012_val_00003603.JPEG',
#  'ILSVRC2012_val_00002939.JPEG',
#  'ILSVRC2012_val_00002051.JPEG',
#  'ILSVRC2012_val_00048624.JPEG',
#  'ILSVRC2012_val_00047831.JPEG',
#  'ILSVRC2012_val_00046194.JPEG',
#  'ILSVRC2012_val_00045629.JPEG',
#  'ILSVRC2012_val_00042880.JPEG',
#  'ILSVRC2012_val_00042740.JPEG',
#  'ILSVRC2012_val_00042645.JPEG',
#  'ILSVRC2012_val_00042378.JPEG',
#  'ILSVRC2012_val_00041533.JPEG',
#  'ILSVRC2012_val_00040579.JPEG',
#  'ILSVRC2012_val_00040336.JPEG',
#  'ILSVRC2012_val_00040144.JPEG',
#  'ILSVRC2012_val_00038865.JPEG',
#  'ILSVRC2012_val_00037856.JPEG',
#  'ILSVRC2012_val_00036707.JPEG',
#  'ILSVRC2012_val_00035782.JPEG',
#  'ILSVRC2012_val_00035198.JPEG',
#  'ILSVRC2012_val_00034661.JPEG',
#  'ILSVRC2012_val_00032802.JPEG',
#  'ILSVRC2012_val_00031510.JPEG',
#  'ILSVRC2012_val_00031165.JPEG',
#  'ILSVRC2012_val_00029044.JPEG',
#  'ILSVRC2012_val_00027382.JPEG',
#  'ILSVRC2012_val_00027015.JPEG',
#  'ILSVRC2012_val_00026875.JPEG',
#  'ILSVRC2012_val_00025860.JPEG',
#  'ILSVRC2012_val_00024003.JPEG',
#  'ILSVRC2012_val_00023831.JPEG',
#  'ILSVRC2012_val_00023547.JPEG',
#  'ILSVRC2012_val_00022428.JPEG',
#  'ILSVRC2012_val_00020845.JPEG',
#  'ILSVRC2012_val_00020834.JPEG',
#  'ILSVRC2012_val_00016850.JPEG',
#  'ILSVRC2012_val_00016676.JPEG',
#  'ILSVRC2012_val_00016551.JPEG',
#  'ILSVRC2012_val_00016320.JPEG',
#  'ILSVRC2012_val_00015775.JPEG',
#  'ILSVRC2012_val_00015317.JPEG',
#  'ILSVRC2012_val_00013823.JPEG',
#  'ILSVRC2012_val_00010802.JPEG',
#  'ILSVRC2012_val_00009389.JPEG',
#  'ILSVRC2012_val_00008622.JPEG',
#  'ILSVRC2012_val_00008350.JPEG',
#  'ILSVRC2012_val_00007768.JPEG',
#  'ILSVRC2012_val_00007326.JPEG',
#  'ILSVRC2012_val_00005406.JPEG',
#  'ILSVRC2012_val_00004566.JPEG',
#  'ILSVRC2012_val_00004066.JPEG',
#  'ILSVRC2012_val_00002885.JPEG',
#  'ILSVRC2012_val_00000722.JPEG',
#  'ILSVRC2012_val_00046576.JPEG',
#  'ILSVRC2012_val_00045886.JPEG',
#  'ILSVRC2012_val_00045842.JPEG',
#  'ILSVRC2012_val_00045722.JPEG',
#  'ILSVRC2012_val_00043793.JPEG',
#  'ILSVRC2012_val_00043628.JPEG',
#  'ILSVRC2012_val_00042081.JPEG',
#  'ILSVRC2012_val_00041656.JPEG',
#  'ILSVRC2012_val_00040588.JPEG',
#  'ILSVRC2012_val_00038817.JPEG',
#  'ILSVRC2012_val_00038470.JPEG',
#  'ILSVRC2012_val_00036594.JPEG',
#  'ILSVRC2012_val_00036508.JPEG',
#  'ILSVRC2012_val_00036025.JPEG',
#  'ILSVRC2012_val_00035777.JPEG',
#  'ILSVRC2012_val_00033601.JPEG',
#  'ILSVRC2012_val_00032931.JPEG',
#  'ILSVRC2012_val_00032211.JPEG',
#  'ILSVRC2012_val_00030800.JPEG',
#  'ILSVRC2012_val_00030548.JPEG',
#  'ILSVRC2012_val_00028183.JPEG',
#  'ILSVRC2012_val_00026695.JPEG',
#  'ILSVRC2012_val_00025503.JPEG',
#  'ILSVRC2012_val_00024267.JPEG',
#  'ILSVRC2012_val_00023568.JPEG',
#  'ILSVRC2012_val_00021815.JPEG',
#  'ILSVRC2012_val_00020317.JPEG',
#  'ILSVRC2012_val_00019579.JPEG',
#  'ILSVRC2012_val_00018938.JPEG',
#  'ILSVRC2012_val_00018473.JPEG',
#  'ILSVRC2012_val_00018047.JPEG',
#  'ILSVRC2012_val_00016235.JPEG',
#  'ILSVRC2012_val_00015078.JPEG',
#  'ILSVRC2012_val_00011999.JPEG',
#  'ILSVRC2012_val_00011462.JPEG',
#  'ILSVRC2012_val_00010512.JPEG',
#  'ILSVRC2012_val_00010186.JPEG',
#  'ILSVRC2012_val_00009813.JPEG',
#  'ILSVRC2012_val_00009723.JPEG',
#  'ILSVRC2012_val_00009120.JPEG',
#  'ILSVRC2012_val_00007537.JPEG',
#  'ILSVRC2012_val_00007189.JPEG',
#  'ILSVRC2012_val_00006365.JPEG',
#  'ILSVRC2012_val_00006277.JPEG',
#  'ILSVRC2012_val_00005586.JPEG',
#  'ILSVRC2012_val_00005128.JPEG',
#  'ILSVRC2012_val_00003787.JPEG',
#  'ILSVRC2012_val_00003059.JPEG',
#  'ILSVRC2012_val_00002612.JPEG',
#  'ILSVRC2012_val_00001579.JPEG',
#  'ILSVRC2012_val_00047874.JPEG',
#  'ILSVRC2012_val_00047348.JPEG',
#  'ILSVRC2012_val_00046504.JPEG',
#  'ILSVRC2012_val_00046268.JPEG',
#  'ILSVRC2012_val_00044419.JPEG',
#  'ILSVRC2012_val_00044332.JPEG',
#  'ILSVRC2012_val_00044175.JPEG',
#  'ILSVRC2012_val_00043142.JPEG',
#  'ILSVRC2012_val_00041534.JPEG',
#  'ILSVRC2012_val_00039921.JPEG',
#  'ILSVRC2012_val_00039502.JPEG',
#  'ILSVRC2012_val_00036415.JPEG',
#  'ILSVRC2012_val_00035435.JPEG',
#  'ILSVRC2012_val_00034058.JPEG',
#  'ILSVRC2012_val_00031490.JPEG',
#  'ILSVRC2012_val_00029779.JPEG',
#  'ILSVRC2012_val_00029578.JPEG',
#  'ILSVRC2012_val_00028997.JPEG',
#  'ILSVRC2012_val_00028390.JPEG',
#  'ILSVRC2012_val_00028309.JPEG',
#  'ILSVRC2012_val_00028083.JPEG',
#  'ILSVRC2012_val_00025705.JPEG',
#  'ILSVRC2012_val_00025342.JPEG',
#  'ILSVRC2012_val_00025204.JPEG',
#  'ILSVRC2012_val_00025160.JPEG',
#  'ILSVRC2012_val_00023329.JPEG',
#  'ILSVRC2012_val_00019244.JPEG',
#  'ILSVRC2012_val_00014919.JPEG',
#  'ILSVRC2012_val_00014445.JPEG',
#  'ILSVRC2012_val_00013636.JPEG',
#  'ILSVRC2012_val_00012324.JPEG',
#  'ILSVRC2012_val_00010935.JPEG',
#  'ILSVRC2012_val_00010858.JPEG',
#  'ILSVRC2012_val_00010262.JPEG',
#  'ILSVRC2012_val_00009737.JPEG',
#  'ILSVRC2012_val_00008589.JPEG',
#  'ILSVRC2012_val_00008068.JPEG',
#  'ILSVRC2012_val_00006776.JPEG',
#  'ILSVRC2012_val_00006115.JPEG',
#  'ILSVRC2012_val_00005680.JPEG',
#  'ILSVRC2012_val_00005602.JPEG',
#  'ILSVRC2012_val_00004881.JPEG',
#  'ILSVRC2012_val_00004739.JPEG',
#  'ILSVRC2012_val_00004131.JPEG',
#  'ILSVRC2012_val_00003663.JPEG',
#  'ILSVRC2012_val_00003391.JPEG',
#  'ILSVRC2012_val_00002188.JPEG',
#  'ILSVRC2012_val_00001999.JPEG',
#  'ILSVRC2012_val_00001794.JPEG',
#  'ILSVRC2012_val_00000433.JPEG',
#  'ILSVRC2012_val_00049033.JPEG',
#  'ILSVRC2012_val_00048036.JPEG',
#  'ILSVRC2012_val_00047188.JPEG',
#  'ILSVRC2012_val_00046780.JPEG',
#  'ILSVRC2012_val_00045163.JPEG',
#  'ILSVRC2012_val_00044134.JPEG',
#  'ILSVRC2012_val_00042958.JPEG',
#  'ILSVRC2012_val_00042261.JPEG',
#  'ILSVRC2012_val_00042085.JPEG',
#  'ILSVRC2012_val_00039228.JPEG',
#  'ILSVRC2012_val_00039210.JPEG',
#  'ILSVRC2012_val_00038799.JPEG',
#  'ILSVRC2012_val_00037415.JPEG',
#  'ILSVRC2012_val_00037267.JPEG',
#  'ILSVRC2012_val_00036134.JPEG',
#  'ILSVRC2012_val_00031783.JPEG',
#  'ILSVRC2012_val_00031393.JPEG',
#  'ILSVRC2012_val_00030144.JPEG',
#  'ILSVRC2012_val_00028123.JPEG',
#  'ILSVRC2012_val_00027884.JPEG',
#  'ILSVRC2012_val_00027835.JPEG',
#  'ILSVRC2012_val_00026841.JPEG',
#  'ILSVRC2012_val_00023741.JPEG',
#  'ILSVRC2012_val_00023176.JPEG',
#  'ILSVRC2012_val_00022231.JPEG',
#  'ILSVRC2012_val_00022108.JPEG',
#  'ILSVRC2012_val_00020184.JPEG',
#  'ILSVRC2012_val_00019974.JPEG',
#  'ILSVRC2012_val_00017793.JPEG',
#  'ILSVRC2012_val_00016751.JPEG',
#  'ILSVRC2012_val_00015424.JPEG',
#  'ILSVRC2012_val_00013910.JPEG',
#  'ILSVRC2012_val_00013568.JPEG',
#  'ILSVRC2012_val_00012987.JPEG',
#  'ILSVRC2012_val_00009356.JPEG',
#  'ILSVRC2012_val_00008400.JPEG',
#  'ILSVRC2012_val_00007504.JPEG',
#  'ILSVRC2012_val_00006911.JPEG',
#  'ILSVRC2012_val_00006772.JPEG',
#  'ILSVRC2012_val_00006542.JPEG',
#  'ILSVRC2012_val_00006309.JPEG',
#  'ILSVRC2012_val_00005839.JPEG',
#  'ILSVRC2012_val_00004166.JPEG',
#  'ILSVRC2012_val_00003510.JPEG',
#  'ILSVRC2012_val_00002814.JPEG',
#  'ILSVRC2012_val_00002731.JPEG',
#  'ILSVRC2012_val_00001235.JPEG',
#  'ILSVRC2012_val_00001211.JPEG',
#  'ILSVRC2012_val_00001196.JPEG',
#  'ILSVRC2012_val_00000535.JPEG',
#  ...]

# %%
img = read_img_numpy()

# %%
np.shape(img)
# Out:
# (3, 224, 224)

# %%
img = Image.fromarray(input_numpy)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/PIL/Image.py:2813, in fromarray(obj, mode)
#    <a href='file:///home/wentaoy/anaconda3/lib/python3.9/site-packages/PIL/Image.py?line=2811'>2812</a> try:
# -> <a href='file:///home/wentaoy/anaconda3/lib/python3.9/site-packages/PIL/Image.py?line=2812'>2813</a>     mode, rawmode = _fromarray_typemap[typekey]
#    <a href='file:///home/wentaoy/anaconda3/lib/python3.9/site-packages/PIL/Image.py?line=2813'>2814</a> except KeyError as e:
#
# KeyError: ((1, 1, 224), '|u1')
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /home/wentaoy/trt2022_levit/LeViT/trt_main.ipynb Cell 19' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bhal-fpga-x86.ncsa.illinois.edu/home/wentaoy/trt2022_levit/LeViT/trt_main.ipynb#ch0000022vscode-remote?line=0'>1</a> img = Image.fromarray(input_numpy)
#
# File ~/anaconda3/lib/python3.9/site-packages/PIL/Image.py:2815, in fromarray(obj, mode)
#    <a href='file:///home/wentaoy/anaconda3/lib/python3.9/site-packages/PIL/Image.py?line=2812'>2813</a>         mode, rawmode = _fromarray_typemap[typekey]
#    <a href='file:///home/wentaoy/anaconda3/lib/python3.9/site-packages/PIL/Image.py?line=2813'>2814</a>     except KeyError as e:
# -> <a href='file:///home/wentaoy/anaconda3/lib/python3.9/site-packages/PIL/Image.py?line=2814'>2815</a>         raise TypeError("Cannot handle this data type: %s, %s" % typekey) from e
#    <a href='file:///home/wentaoy/anaconda3/lib/python3.9/site-packages/PIL/Image.py?line=2815'>2816</a> else:
#    <a href='file:///home/wentaoy/anaconda3/lib/python3.9/site-packages/PIL/Image.py?line=2816'>2817</a>     rawmode = mode
#
# TypeError: Cannot handle this data type: (1, 1, 224), |u1

# %%
np.shape(out.transpose(2,0,1))
# Out:
# (3, 375, 500)
